# %% [markdown]
# 📒 01_load_and_explore.ipynb
#
# 👉 ONLY:
#
# Load JSON
# Understand structure
# Check columns
#
# ❌ No cleaning
# ❌ No modeling

# %% [markdown]
# Get the data safely and understand what you’re dealing with.
#
# Loads the large Enron JSON
# Converts it to a DataFrame
# Removes junk rows (.DS_Store, empty bodies)
# Shows head(), info(), distributions, basic stats

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\singh\Desktop\Sem 6\NLP\Project\email-overload-organizer\.venv\Lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\singh\Desktop\Sem 6\NLP\Project\email-overload-organizer\.venv\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\singh\Desktop\Sem 6\NLP\Project\email-overload-organizer\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\singh\Desktop\Sem 6\NLP\Project\email-overload-organizer\.venv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\singh\Desktop\Sem 6\NLP\Project\email-overload-organizer\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# pandas is used to store, clean, and work with your emails in a table format, so you can easily filter, modify, and analyze them before deciding which emails are important.

# %%
import json
import pandas as pd

file_path = "../data/raw/cleaned_enron_emails.json"
MAX_ROWS = 200000  # keep this capped unless you have high RAM

def stream_json_array(path, max_rows=None, chunk_size=1024 * 1024):
    decoder = json.JSONDecoder()
    items = []

    with open(path, "r", encoding="utf-8") as f:
        # find opening [
        while True:
            ch = f.read(1)
            if not ch:
                raise ValueError("Empty JSON file")
            if ch.isspace():
                continue
            if ch != "[":
                raise ValueError("Expected top-level JSON array")
            break

        buf = ""
        pos = 0
        eof = False

        while True:
            # top up buffer
            if not eof and (len(buf) - pos) < chunk_size:
                part = f.read(chunk_size)
                if part:
                    buf += part
                else:
                    eof = True

            # skip whitespace without copying buffer
            while pos < len(buf) and buf[pos].isspace():
                pos += 1

            if pos >= len(buf):
                if eof:
                    break
                if pos > 0:
                    buf = ""
                    pos = 0
                continue

            ch = buf[pos]
            if ch == "]":
                break
            if ch == ",":
                pos += 1
                continue

            try:
                obj, next_pos = decoder.raw_decode(buf, pos)
            except json.JSONDecodeError:
                if eof:
                    raise
                # compact consumed part only
                if pos > 0:
                    buf = buf[pos:]
                    pos = 0
                continue

            items.append(obj)
            pos = next_pos

            if max_rows is not None and len(items) >= max_rows:
                break

            # periodic compaction
            if pos > 2 * chunk_size:
                buf = buf[pos:]
                pos = 0

    return items

data = stream_json_array(file_path, max_rows=MAX_ROWS)
df = pd.DataFrame(data)


# Optional but recommended: remove junk macOS files
df = df[df["Filename"] != ".DS_Store"]
df = df[df["Body"].str.strip() != ""]

df.reset_index(drop=True, inplace=True)

df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 199673 entries, 0 to 199672
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   From       199673 non-null  str
#  1   To         199673 non-null  str
#  2   Subject    199673 non-null  str
#  3   Date       199673 non-null  str
#  4   Body       199673 non-null  str
#  5   ThreadKey  199673 non-null  str
#  6   Filename   199673 non-null  str
# dtypes: str(7)
# memory usage: 10.7 MB

# %%
# clean the email dates and create year/month columns for time-based analysis.
df["Date"] = pd.to_datetime(
    df["Date"],
    errors="coerce",
    utc=True   
)

df = df.dropna(subset=["Date"])
df["year"] = df["Date"].dt.year
df["month"] = df["Date"].dt.month

# %%
# normalize email text so it’s clean and consistent for NLP tasks
import re
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text.strip()

df["clean_body"] = df["Body"].apply(preprocess_text)
df["clean_subject"] = df["Subject"].fillna("").apply(preprocess_text)

# %%
# create useful metadata features (length, recipients count, sender domain) for analyzing or prioritizing emails.
df["email_length"] = df["clean_body"].apply(len)
df["num_recipients"] = df["To"].apply(lambda x: len(str(x).split(",")))

df["sender_domain"] = df["From"].apply(
    lambda x: x.split("@")[-1] if isinstance(x, str) and "@" in x else "unknown"
)

# %%
# auto-label emails as important or not using keyword matching + negation handling.
IMPORTANT_KEYWORDS = [
    "meeting", "deadline", "urgent", "contract",
    "invoice", "report", "approval", "schedule",
    "finance", "budget", "allocation"
]

NEGATED_URGENCY_PATTERNS = [
    "no urgent", "not urgent", "nothing urgent", "no urgent updates",
    "no immediate action", "not time sensitive"
]

kw_pattern = "|".join(re.escape(k) for k in IMPORTANT_KEYWORDS)
neg_pattern = "|".join(re.escape(p) for p in NEGATED_URGENCY_PATTERNS)
non_urgent_keywords = [k for k in IMPORTANT_KEYWORDS if k != "urgent"]
non_urgent_pattern = "|".join(re.escape(k) for k in non_urgent_keywords)

labels = pd.Series(0, index=df.index, dtype="int8")
chunk_size = 50000

for start in range(0, len(df), chunk_size):
    end = min(start + chunk_size, len(df))
    chunk = (df.iloc[start:end]["clean_subject"].fillna("") + " " + df.iloc[start:end]["clean_body"].fillna("")).str.lower()

    has_important = chunk.str.contains(kw_pattern, regex=True)
    has_negated_urgency = chunk.str.contains(neg_pattern, regex=True)
    has_non_urgent_importance = chunk.str.contains(non_urgent_pattern, regex=True)

    labels.iloc[start:end] = (has_important & ~(has_negated_urgency & ~has_non_urgent_importance)).astype("int8")

df["label"] = labels

# %%
# 1 is important email
df["label"].value_counts()
# Out:
# label
# 0    121389
# 1     78284
# Name: count, dtype: int64

# %%
output_path = "../data/processed/emails_with_labels.csv"
df.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: ../data/processed/emails_with_labels.csv
