# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.2-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/suhanisinghania/Desktop/email-overload-organizer/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/suhanisinghania/Desktop/email-overload-organizer/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.0-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.3 MB/s  0:00:07m0:00:0100:01
# Downloading numpy-2.4.2-cp314-cp314-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 1.3 MB/s  0:00:04 eta 0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.2 pandas-3.0.0

# %%
import json
import pandas as pd

file_path = "../data/raw/cleaned_enron_emails.json"

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# data is already a list of email dictionaries
df = pd.DataFrame(data)

# Optional but recommended: remove junk macOS files
df = df[df["Filename"] != ".DS_Store"]
df = df[df["Body"].str.strip() != ""]

df.reset_index(drop=True, inplace=True)

df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 516793 entries, 0 to 516792
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   From       516793 non-null  str
#  1   To         516793 non-null  str
#  2   Subject    516793 non-null  str
#  3   Date       516793 non-null  str
#  4   Body       516793 non-null  str
#  5   ThreadKey  516793 non-null  str
#  6   Filename   516793 non-null  str
# dtypes: str(7)
# memory usage: 27.6 MB

# %%
df["Date"] = pd.to_datetime(
    df["Date"],
    errors="coerce",
    utc=True   
)

df = df.dropna(subset=["Date"])
df["year"] = df["Date"].dt.year
df["month"] = df["Date"].dt.month

# %%
import re
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text.strip()

df["clean_body"] = df["Body"].apply(preprocess_text)
df["clean_subject"] = df["Subject"].fillna("").apply(preprocess_text)

# %%
df["email_length"] = df["clean_body"].apply(len)
df["num_recipients"] = df["To"].apply(lambda x: len(str(x).split(",")))

df["sender_domain"] = df["From"].apply(
    lambda x: x.split("@")[-1] if isinstance(x, str) and "@" in x else "unknown"
)

# %%
IMPORTANT_KEYWORDS = [
    "meeting", "deadline", "urgent", "contract",
    "invoice", "report", "approval", "schedule"
]

def label_importance(body, subject):
    combined = f"{subject} {body}"
    for kw in IMPORTANT_KEYWORDS:
        if kw in combined:
            return 1
    return 0

df["label"] = df.apply(
    lambda x: label_importance(x["clean_body"], x["clean_subject"]),
    axis=1
)

# %%
df["label"].value_counts()
# Out:
# label
# 0    320189
# 1    196604
# Name: count, dtype: int64

# %%
output_path = "../data/processed/emails_with_labels.csv"
df.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: ../data/processed/emails_with_labels.csv
