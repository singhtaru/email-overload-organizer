# %% [markdown]
# 📒 02_preprocessing.ipynb
#
# 👉 Does:
#
# Cleaning
# Text normalization
# Feature creation
# Label creation
#
# 👉 OUTPUT:

# %% [markdown]
# Turn raw emails into machine-understandable input.
#
# Text cleaning (lowercase, remove symbols)
# Date parsing (year, month)
# Feature engineering (email length, sender domain, recipients)
# Keyword-based labeling (0 / 1)

# %%
#Load raw Enron JSON
import re
import json
import pandas as pd

file_path = "../data/raw/cleaned_enron_emails.json"
MAX_ROWS = 200000  # keep this capped unless you have high RAM

def stream_json_array(path, max_rows=None, chunk_size=1024 * 1024):
    decoder = json.JSONDecoder()
    items = []

    with open(path, "r", encoding="utf-8") as f:
        # find opening [
        while True:
            ch = f.read(1)
            if not ch:
                raise ValueError("Empty JSON file")
            if ch.isspace():
                continue
            if ch != "[":
                raise ValueError("Expected top-level JSON array")
            break

        buf = ""
        pos = 0
        eof = False

        while True:
            # top up buffer
            if not eof and (len(buf) - pos) < chunk_size:
                part = f.read(chunk_size)
                if part:
                    buf += part
                else:
                    eof = True

            # skip whitespace without copying buffer
            while pos < len(buf) and buf[pos].isspace():
                pos += 1

            if pos >= len(buf):
                if eof:
                    break
                if pos > 0:
                    buf = ""
                    pos = 0
                continue

            ch = buf[pos]
            if ch == "]":
                break
            if ch == ",":
                pos += 1
                continue

            try:
                obj, next_pos = decoder.raw_decode(buf, pos)
            except json.JSONDecodeError:
                if eof:
                    raise
                # compact consumed part only
                if pos > 0:
                    buf = buf[pos:]
                    pos = 0
                continue

            items.append(obj)
            pos = next_pos

            if max_rows is not None and len(items) >= max_rows:
                break

            # periodic compaction
            if pos > 2 * chunk_size:
                buf = buf[pos:]
                pos = 0

    return items

data = stream_json_array(file_path, max_rows=MAX_ROWS)
df = pd.DataFrame(data)


df.head()
# Out:
#                       From                                                 To  \
# 0
# 1
# 2          msagel@home.com                                  jarnold@enron.com
# 3  slafontaine@globalp.com                              john.arnold@enron.com
# 4  iceoperations@intcx.com  icehelpdesk@intcx.com, internalmarketing@intcx...
#
#                          Subject                             Date  \
# 0
# 1
# 2                         Status  Thu, 16 Nov 2000 09:30:00 -0800
# 3             re:summer inverses  Fri, 08 Dec 2000 05:05:00 -0800
# 4  The WTI Bullet swap contracts  Tue, 15 May 2001 09:43:00 -0700
#
#                                                 Body  \
# 0
# 1
# 2  John:\n?\nI'm not really sure what happened be...
# 3  i suck-hope youve made more money in natgas la...
# 4  Hi,\n\n\nFollowing the e-mail you have receive...
#
#                                            ThreadKey   Filename
# 0                                                 ::  .DS_Store
# ...

# %%
#Data cleaning (noise removal)
# Remove macOS junk files
df = df[df["Filename"] != ".DS_Store"]

# Remove empty bodies
df = df[df["Body"].str.strip() != ""]

df.reset_index(drop=True, inplace=True)

# %%
#Date normalization (timezone-safe)
df["Date"] = pd.to_datetime(
    df["Date"],
    errors="coerce",
    utc=True
)

df = df.dropna(subset=["Date"])
df["year"] = df["Date"].dt.year
df["month"] = df["Date"].dt.month

# %%
# Text preprocessing 
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text.strip()

df["clean_body"] = df["Body"].apply(preprocess_text)
df["clean_subject"] = df["Subject"].fillna("").apply(preprocess_text)

# %%
# Feature engineering
df["email_length"] = df["clean_body"].apply(len)

df["num_recipients"] = df["To"].apply(
    lambda x: len(str(x).split(","))
)

df["sender_domain"] = df["From"].apply(
    lambda x: x.split("@")[-1] if isinstance(x, str) and "@" in x else "unknown"
)

# %%
# Weak supervision (label creation)
IMPORTANT_KEYWORDS = [
    "meeting", "deadline", "urgent", "contract",
    "invoice", "report", "approval", "schedule",
    "finance", "budget", "allocation"
]

NEGATED_URGENCY_PATTERNS = [
    "no urgent", "not urgent", "nothing urgent", "no urgent updates",
    "no immediate action", "not time sensitive"
]

kw_pattern = "|".join(re.escape(k) for k in IMPORTANT_KEYWORDS)
neg_pattern = "|".join(re.escape(p) for p in NEGATED_URGENCY_PATTERNS)
non_urgent_keywords = [k for k in IMPORTANT_KEYWORDS if k != "urgent"]
non_urgent_pattern = "|".join(re.escape(k) for k in non_urgent_keywords)

labels = pd.Series(0, index=df.index, dtype="int8")
chunk_size = 50000

for start in range(0, len(df), chunk_size):
    end = min(start + chunk_size, len(df))
    chunk = (df.iloc[start:end]["clean_subject"].fillna("") + " " + df.iloc[start:end]["clean_body"].fillna("")).str.lower()

    has_important = chunk.str.contains(kw_pattern, regex=True)
    has_negated_urgency = chunk.str.contains(neg_pattern, regex=True)
    has_non_urgent_importance = chunk.str.contains(non_urgent_pattern, regex=True)

    labels.iloc[start:end] = (has_important & ~(has_negated_urgency & ~has_non_urgent_importance)).astype("int8")

df["label"] = labels

# %%
df["label"].value_counts()
# Out:
# label
# 0    121389
# 1     78284
# Name: count, dtype: int64

# %%
# Save ML-ready dataset
output_path = "../data/processed/emails_with_labels.csv"
df.to_csv(output_path, index=False)

print("Saved preprocessed dataset to:", output_path)
# Out:
# Saved preprocessed dataset to: ../data/processed/emails_with_labels.csv
